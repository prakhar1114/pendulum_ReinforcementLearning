# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
a=np.load('ActorCriticSoftmax_tilings_32_tiledim_8_actor_ss_0.25_critic_ss_2_avg_reward_ss_0.015625_exp_avg_reward.npy')
b=np.load('ActorCriticSoftmax_tilings_32_tiledim_8_actor_ss_0.25_critic_ss_2_avg_reward_ss_0.015625_total_return.npy')

# %%
print(a)
# Out:
# [[-7.92685023e+00 -7.81198525e+00 -7.71712024e+00 ... -2.83326827e-03
#   -2.81892707e-03 -2.83414153e-03]
#  [-7.92685023e+00 -7.81198525e+00 -7.73668374e+00 ... -2.97763314e-03
#   -2.99625895e-03 -2.98162288e-03]
#  [-7.92685023e+00 -7.81198525e+00 -7.71712024e+00 ... -6.14056604e+00
#   -6.13170083e+00 -6.11012821e+00]
#  ...
#  [-7.92785023e+00 -7.82424661e+00 -7.74746611e+00 ... -6.17368009e+00
#   -6.20994393e+00 -6.23232818e+00]
#  [-7.92785023e+00 -7.82374410e+00 -7.75801134e+00 ... -4.38774469e+00
#   -4.36789347e+00 -4.34122570e+00]
#  [-7.92685023e+00 -7.81198525e+00 -7.73668374e+00 ... -3.86149732e-03
#   -3.84532800e-03 -3.83493779e-03]]

# %%
print(a.shape)
# Out:
# (50, 20000)

# %%
a_mean=np.mean(a,axis=0)
print(a_mean.shape)
# Out:
# (20000,)

# %%
print(b.shape)
# Out:
# (50, 20000)

# %%
b_mean=np.mean(b,axis=0)
print(b_mean.shape)
c=np.array([i for i in range(b_mean.shape[0])])
# Out:
# (20000,)

# %%
plt.plot(c,a_mean)
plt.show()

# %%
plt.plot(c,b_mean)
plt.show()

# %%
a=np.load('exp_average_return_1.98.npy')
b=np.load('total_return_1.98.npy')
print(a.shape)
print(b.shape)

a_mean=np.mean(a,axis=0)
# b_mean=np.mean(b,axis=1)
b_mean=b
print(a_mean.shape[0])
print(b.shape)
print(b_mean.shape[0])
# Out:
# (10, 20000)
# (20000,)
# 20000
# (20000,)
# 20000

# %%
c=np.array([i for i in range(b_mean.shape[0])])
plt.plot(c,a_mean)
plt.show()
plt.plot(c,b_mean)
plt.show()
